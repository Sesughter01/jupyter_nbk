# %%
import pymysql.cursors


def write_to_db(customer, amount,collectionDate,tenor):
    # Connect to the database
    connection = pymysql.connect(host='localhost',
                             user='root',
                             password='Kelikume11&&',
                             database='interbank',
                             cursorclass=pymysql.cursors.DictCursor)

    with connection:
        with connection.cursor() as cursor:
            # Create a new record
            sql = "INSERT INTO `disbursements` (accountName, amountNumber,BVN, accountStatus) VALUES ('{0}', '{1}','{2}','{3}')"
            cursor.execute(sql.format(accountName, amountNumber,BVN, accountStatus))

        # connection is not autocommit by default. So you must commit to save
        # your changes.
            connection.commit()

# %%
import pymysql.cursors
# Connect to the database
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='Kelikume11&&',
                             database='school',
                             cursorclass=pymysql.cursors.DictCursor)

with connection:
    with connection.cursor() as cursor:
        # Create a new record
        sql = "SELECT `name`, `age` , `deptID` FROM `student` "
        cursor.execute(sql)

    # connection is not autocommit by default. So you must commit to save
    # your changes.
    # connection.commit()

    # with connection.cursor() as cursor:
        # Read a single record
      
        result = cursor.fetchmany(5)
        print(result)
# Out:
# [{'name': 'Adaora', 'age': 21, 'deptID': 1}, {'name': 'Kunle', 'age': 24, 'deptID': 2}, {'name': 'John', 'age': 21, 'deptID': 1}, {'name': 'Sam', 'age': 21, 'deptID': 2}, {'name': 'Susan', 'age': 20, 'deptID': 3}]

# %%
import pymysql.cursors
# Connect to the database
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='Kelikume11&&',
                             database='school',
                             cursorclass=pymysql.cursors.DictCursor)

with connection:
    with connection.cursor() as cursor:
        # Create a new record
        sql = "SELECT `name`, `age` , `deptID` FROM `student` WHERE `age` =%s AND `deptID`=%s "
        cursor.execute(sql, (21,1))

    # connection is not autocommit by default. So you must commit to save
    # your changes.
    # connection.commit()

    # with connection.cursor() as cursor:
        # Read a single record
      
        result = cursor.fetchall()
        print(result)
# Out:
# [{'name': 'Adaora', 'age': 21, 'deptID': 1}, {'name': 'John', 'age': 21, 'deptID': 1}]

# %%
import csv

with open('Loan-2022-02-27.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    print(list(csv_reader))
#     line_count = 0
#     for row in csv_reader:
#         if line_count == 0:
#             print(f'\t{row[1].ljust(15)}  {row[3].ljust(25)} {row[5].ljust(15)} {row[14].rjust(9)} {row[9].rjust(9)} \n')
#             line_count += 1
#         else:
#             print(f'\t{row[1].ljust(15)}  {row[3].ljust(25)} {row[5].ljust(15)} {row[14].rjust(9)} {row[9].rjust(9)} \n')
#             write_to_db(row[1],row[3],row[5],row[9])
#             line_count += 1
#     print(f'Processed {line_count} lines.')
# print(list(csv_reader))
# Out:
# [['id', 'customerId', 'currency', 'loanAmount', 'elgible_amount', 'dateOfDisbursement', 'dateOfCollection', 'due_date', 'totalCollectionAmount', 'numberOfRepayments', 'mandateReference', 'loan_disk_id', 'loan_status', 'average_salary', 'loan_obligation', 'monthly_repayment', 'loan_comment', 'paid_amount', 'last_paid_amount', 'last_paid_date', 'outstanding_loan_bal', 'remita_loan_repayment_ref', 'eligible_id', 'repayment_id', 'mandate_close', 'repayment_count', 'loan_percentage_taken', 'eligible_for_top_up', 'topup_eligible_amount'], ['8907', 'r_10398033', 'Naira', '25200', '11639', '2/26/2022 17:20', '2/26/2022 17:21', '5/26/2022 17:20', '35028', '3', '3.01E+11', '2757729', '1', '120666.8', '104040', '11700', 'open', '0', '', '', '', '', '93533', '', '0', '', '', '1', '0'], ['8906', 'r_11371726', 'Naira', '8100', '2374', '2/26/2022 16:47', '2/26/2022 16:49', '8/26/2022 16:48', '14418', '6', '3.51E+11', '2757695', '1', '9690.6', '6300', '2500', 'open', '0', '', '', '', '', '93357', ''
# ...

# %%
import pymysql.cursors
# Connect to the database
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='Kelikume11&&',
                             database='loans',
                             cursorclass=pymysql.cursors.DictCursor)


def write_to_db(customer, amount,collectionDate,tenor):
    with connection:
        with connection.cursor() as cursor:
            # Create a new record
            sql = "INSERT INTO `disbursements` (customer, amount,collectionDate, tenor) VALUES ('{0}', '{1}','{2}','{3}')"
            cursor.execute(sql.format(customer, amount,collectionDate, tenor))

    # connection is not autocommit by default. So you must commit to save
    # your changes.
        connection.commit()

# %%
write_to_db(1,2,3,4)

# %%
import pymysql.cursors
# Connect to the database
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='Kelikume11&&',
                             database='loans',
                             cursorclass=pymysql.cursors.DictCursor)

with connection:
    with connection.cursor() as cursor:
        # Create a new record
#         sql = "SELECT  *  FROM `disbursements` LIMIT 30 "
        sql = "SELECT   customer, amount, collectionDate  FROM `disbursements` ORDER BY amount  DESC LIMIT 30 "
        cursor.execute(sql)

    # connection is not autocommit by default. So you must commit to save
    # your changes.
    # connection.commit()

    # with connection.cursor() as cursor:
        # Read a single record
      
        result = cursor.fetchmany(30)
        column_head_1='customer'
        column_head_2='amount'
        column_head_3='collectionDate'
        print(f'\t{column_head_1.ljust(15)} {column_head_2.ljust(20)} {column_head_3.rjust(10)}\n')
        for row in result:

            column_data_1=row['customer']
            column_data_2=str(row['amount'])
            column_data_3=row['collectionDate']

            print(f'\t{column_data_1.ljust(15)} {column_data_2.ljust(20)} {column_data_3.rjust(10)}\n')

               
    print(f'Processed {line_count} lines.')
# Out:
# 	customer        amount               collectionDate
#
# 	r_10054551      800000.0             2/23/2022 15:32
#
# 	r_10981320      675000.0             2/2/2022 20:04
#
# 	r_2001900979    453500.0             2/7/2022 20:58
#
# 	r_11175761      332400.0             2/4/2022 14:16
#
# 	r_2001684419    303100.0             2/23/2022 21:08
#
# 	r_2000629576    300900.0             2/12/2022 12:51
#
# 	r_2001742209    300900.0             2/14/2022 17:41
#
# 	r_2000633220    275800.0             2/12/2022 13:36
#
# 	r_11459015      266724.0             2/19/2022 16:23
#
# 	r_2000697228    266400.0             2/25/2022 20:58
#
# 	r_2002488669    263500.0             2/19/2022 17:55
#
# 	r_10550392      259800.0             2/16/2022 18:06
#
# 	r_8698860498    259600.0             2/23/2022 21:58
#
# 	r_2002334116    256800.0             2/14/2022 21:34
#
# 	r_2002029650    253500.0             2/24/2022 13:51
#
# 	r_2001582498    244300.0             2/24/2022 14:32
#
# ...

# %%
# !pip install pandas
# Out:
# ...
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\users\charles\appdata\local\programs\python\python37\lib\site-packages\pip\_vendor\urllib3\response.py", line 425, in _error_catcher
#     yield
#   File "c:\users\charles\appdata\local\programs\python\python37\lib\site-packages\pip\_vendor\urllib3\response.py", line 507, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "c:\users\charles\appdata\local\programs\python\python37\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "c:\users\charles\appdata\local\programs\python\python37\lib\http\client.py", line 461, in read
#     n = self.readinto(b)
#   File "c:\users\charles\appdata\local\programs\python\python37\lib\http\client.py", line 505, in readinto
#     n = self.fp.readinto(b)
#   File "c:\users\charles\appdata\local\programs\python\python37\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ...
